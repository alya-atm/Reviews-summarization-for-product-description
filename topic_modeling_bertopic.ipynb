# %%
import pandas as pd
import gensim
import gensim.corpora as corpora
from gensim.models.coherencemodel import CoherenceModel
from gensim.models import Nmf, LdaModel
import plotly.graph_objs as go
import plotly.io as pio
pio.renderers.default='notebook'
from bertopic import BERTopic
from umap import UMAP
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
comments = pd.read_csv('comments_clean.csv')

# %% [markdown]
# # BERTopic

# %%
docs = comments.clean_body.to_list()

# %%
umap_model = UMAP(n_neighbors=100, 
                  n_components=10, 
                  metric ='cosine', 
                  random_state=100)

# %%
model = BERTopic(language="russian", verbose = True, nr_topics=100)
#model.reduce_topics(docs, nr_topics=100)

# %%
topics, probs = model.fit_transform(docs)
# Out:
# Batches:   0%|          | 0/7068 [00:00<?, ?it/s]
# 2022-12-26 19:28:40,773 - BERTopic - Transformed documents to Embeddings
# 2022-12-26 19:30:48,189 - BERTopic - Reduced dimensionality
# 2022-12-26 19:31:03,701 - BERTopic - Clustered reduced embeddings
# 2022-12-26 19:32:31,487 - BERTopic - Reduced number of topics from 1541 to 101

# %%
topic_info = model.get_topic_info()

# %%
model.get_topic(2)
# Out:
# [('краска', 0.05429293804646796),
#  ('цвет', 0.03557368048768363),
#  ('красить', 0.03013561179194114),
#  ('слой', 0.027287003461947897),
#  ('банка', 0.02121166858311329),
#  ('белый', 0.01830594242537827),
#  ('покрасить', 0.01763762311075046),
#  ('ложиться', 0.013466149834927908),
#  ('банк', 0.013057215773057084),
#  ('покраска', 0.01186323870923308)]

# %%
model.save("berttopic_100")
# Out:
# /Users/alyaatmaeva/bertopic/env/lib/python3.9/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning:
#
# Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.

# %%
model.reduce_topics(docs, nr_topics=85)
# Out:
# 2022-12-26 19:49:08,878 - BERTopic - Reduced number of topics from 91 to 86

# %%
model.visualize_hierarchy()
# Out:
# <div>                            <div id="1e8085a6-fde0-427a-a7f6-583d8c8363ae" class="plotly-graph-div" style="height:1475px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1e8085a6-fde0-427a-a7f6-583d8c8363ae")) {                    Plotly.newPlot(                        "1e8085a6-fde0-427a-a7f6-583d8c8363ae",                        [{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.0,1.1576907483840506,1.1576907483840506,0.0],"xaxis":"x","y":[-15.0,-15.0,-25.0,-25.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.0,1.183786549856,1.183786549856,1.1576907483840506],"xaxis":"x","y":[-5.0,-5.0,-20.0,-20.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.0,1.1070111103324667,1.1070111103324667,0.0],"xaxis":"x","y":[-45.0,-45.0,-55.0,-55.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.0,1.2520781974479753,1.2520781974479753,1.1070111103324667],"xaxis":"x","y":[-35.0,-35.0,-50.0,-50.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[1.183786549856,1.4822487873995511,1.4822487873995511,1.2520781974479753],"xaxis":"x","y":[-12.5,-12.5,-42.5,-42.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.0,1.2281887505782076,1.2281887505782076,0.0],"xaxis":"x","y":[-65.0,-65.0,-75.0,-75.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.0,1.2634952171347371,1.2634952171347371,0.0],"xaxis":"x","y":[-85.0,-85.0,-95.0,-95.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.0,1.2423236325148475,1.2423236325148475,0.0],"xaxis":"x","y":[-115.0,-115.0,-125.0,-125.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.0,1.3034515935241149,1.3034515935241149,1.2423236325148475],"xaxis":"x","y":[-105.0,-105.0,-120.0,-120.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[1.3034515935241149,1.3167131183018075,1.3167131183018075,0.0],"xaxis":"x","y":[-112.5,-112.5,-135.0,-135.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[1.2634952171347371,1.3418023913262376,1.3418023913262376,1.3167131183018075],"xaxis":"x","y":[-90.0,-90.0,-123.75,-123.75],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.0,1.3218725498847734,1.3218725498847734,0.0],"xaxis":"x","y":[-145.0,-145.0,-155.0,-155.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[1.3218725498847734,1.3468419907792717,1.3468419907792717,0.0],"xaxis":"x","y":[-150.0,-150.0,-165.0,-165.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[1.3418023913262376,1.4777507976872868,1.4777507976872868,1.3468419907792717],"xaxis":"x","y":[-106.875,-106.875,-157.5,-157.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[1.2281887505782076,1.5065598871574573,1.5065598871574573,1.4777507976872868],"xaxis":"x","y":[-70.0,-70.0,-132.1875,-132.1875],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.0,1.167725018961012,1.167725018961012,0.0],"xaxis":"x","y":[-175.0,-175.0,-185.0,-185.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.0,1.276446970404635,1.276446970404635,0.0],"x ...

# %%
model.visualize_barchart(top_n_topics=12)
# Out:
# <div>                            <div id="64f8db48-3d8b-444f-a8a1-8f678e06b49a" class="plotly-graph-div" style="height:750px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("64f8db48-3d8b-444f-a8a1-8f678e06b49a")) {                    Plotly.newPlot(                        "64f8db48-3d8b-444f-a8a1-8f678e06b49a",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.009027312972088385,0.0095213827172487,0.009870543412063136,0.010902213759624028,0.015085758362615687],"y":["\u043a\u0443\u043f\u0438\u0442\u044c  ","\u0442\u043e\u0432\u0430\u0440  ","\u043e\u0442\u0437\u044b\u0432  ","\u043b\u0435\u0440\u0443\u0430  ","\u043c\u0430\u0433\u0430\u0437\u0438\u043d  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.016981831327278558,0.017304753232514222,0.018525141809721247,0.020403273254011988,0.15006864289298022],"y":["\u043a\u043e\u0440\u043e\u0431\u043a\u0430  ","\u0433\u0435\u043e\u043c\u0435\u0442\u0440\u0438\u044f  ","\u043a\u0440\u0438\u0432\u043e\u0439  ","\u0443\u043a\u043b\u0430\u0434\u043a\u0430  ","\u043f\u043b\u0438\u0442\u043a\u0430  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.02121166858311329,0.027287003461947897,0.03013561179194114,0.03557368048768363,0.05429293804646796],"y":["\u0431\u0430\u043d\u043a\u0430  ","\u0441\u043b\u043e\u0439  ","\u043a\u0440\u0430\u0441\u0438\u0442\u044c  ","\u0446\u0432\u0435\u0442  ","\u043a\u0440\u0430\u0441\u043a\u0430  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.018303496605334733,0.019056005596868097,0.025371601486477838,0.03071986131102818,0.11053618172555414],"y":["\u043a\u0443\u0445\u043e\u043d\u043d\u044b\u0439  ","\u043f\u0430\u043d\u0435\u043b\u044c  ","\u043a\u043e\u0440\u0438\u0434\u043e\u0440  ","\u0448\u043a\u0430\u0444  ","\u043a\u0443\u0445\u043d\u044f  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.0133397165353866,0.013836358983383775,0.016550031099045584,0.02635541016588441,0.12823733520193578],"y":["\u043c\u0430\u0433\u0430\u0437\u0438\u043d  ","\u043b\u0430\u043c\u0438\u043d\u0430\u0442  ","\u043f\u043e\u043f\u0430\u0434\u0430\u0442\u044c\u0441\u044f  ","\u043c\u0443\u0436  ","\u0431\u0440\u0430\u043a  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.019043852955292297,0.024908817163405424,0.0263112130094275,0.038220768929524716,0.08938427764950233],"y":["\u043f\u0440\u043e\u0444\u0438\u043b\u044c  ","\u043c\u0435\u0442\u0430\u043b\u043b\u0438\u0447\u0435\u0441\u043a\u0438\u0439  ","\u043c\u0430\u043d\u0433\u0430\u043b  ","\u0441\u0442\u0430\u043b\u044c  ","\u043c\u0435\u0442\u0430\u043b\u043b  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.018383966819588354,0.03177510590316612,0.03538796222580274,0.06467992602644707,0.09727675994100285],"y":["\u0438\u0437\u043e\u043b\u044f\u0446\u0438\u044f  ","\u043a\u0430\u043d\u0430\u043b  ","\u0430\u043d\u0442\u0435\u043d\u043d\u0430  ","\u043f\u0440\u043e\u0432\u043e\u0434  ","\u043a\u0430\u0431\u0435\u043b\u044c  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.016309049024573474,0.01686801206341832,0.019075375896046735,0.030096821620262733,0.03231859338945553],"y":["\u0441\u0430\u043c\u043e\u0440\u0435\u0437  ","\u043e\u0442\u0432\u0435\u0440\u0441\u0442\u0438\u0435  ","\u043a\u0440\u0435\u043f\u043b\u0435\u043d\u0438\u0435  ","\u0441\u043b\u043e\u043c\u0430\u0442\u044c\u0441\u044f  ","\u043a\u043e\u043b\u044c\u0446\u043e  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.05878203494686974,0.07310298763841812,0.07 ...

# %%
model.visualize_topics(top_n_topics=100)
# Out:
# <div>                            <div id="f8ffb314-4269-4f8d-8af9-a74acb91c0cd" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f8ffb314-4269-4f8d-8af9-a74acb91c0cd")) {                    Plotly.newPlot(                        "f8ffb314-4269-4f8d-8af9-a74acb91c0cd",                        [{"customdata":[[0,"\u0432\u0430\u043d\u043d\u0430 | \u0432\u0430\u043d\u043d\u044b\u0439 | \u0432\u0430\u043d\u043d\u0430\u044f | \u0442\u0443\u0430\u043b\u0435\u0442 | \u043a\u043e\u043c\u043d\u0430\u0442\u0430",4848],[1,"\u043a\u0443\u0445\u043d\u044f | \u0448\u043a\u0430\u0444 | \u0441\u0442\u043e\u043b\u0435\u0448\u043d\u0438\u0446\u0430 | \u043a\u0443\u0445\u043e\u043d\u043d\u044b\u0439 | \u0444\u0430\u0440\u0442\u0443\u043a",3396],[2,"\u0431\u0440\u0430\u043a | \u043c\u0443\u0436 | \u043f\u043e\u043f\u0430\u0434\u0430\u0442\u044c\u0441\u044f | \u043f\u0430\u0447\u043a\u0430 | \u0432\u0430\u0433\u043e\u043d\u043a\u0430",2520],[3,"\u043a\u0430\u0431\u0435\u043b\u044c | \u043f\u0440\u043e\u0432\u043e\u0434 | \u0430\u043d\u0442\u0435\u043d\u043d\u0430 | \u043a\u0430\u043d\u0430\u043b | \u0441\u0438\u0433\u043d\u0430\u043b",2234],[4,"\u043c\u0435\u0442\u0430\u043b\u043b | \u0441\u0442\u0430\u043b\u044c | \u043c\u0430\u043d\u0433\u0430\u043b | \u043c\u0435\u0442\u0430\u043b\u043b\u0438\u0447\u0435\u0441\u043a\u0438\u0439 | \u0443\u0433\u043e\u043b\u044c",2057],[5,"\u043a\u0432\u0430\u0440\u0442\u0438\u0440\u0430 | \u0434\u043e\u043c | \u0440\u0435\u043c\u043e\u043d\u0442 | \u0441\u043e\u0432\u0435\u0442\u043e\u0432\u0430\u0442\u044c | \u0434\u043e\u043c\u0430\u0448\u043d\u0438\u0439",2007],[6,"\u0435\u043b\u043a\u0430 | \u0434\u0435\u0440\u0435\u0432\u043e | \u0435\u043b\u043e\u0447\u043a\u0430 | \u043f\u0443\u0448\u0438\u0441\u0442\u044b\u0439 | \u043a\u0440\u0430\u0441\u0438\u0432\u044b\u0439",1964],[7,"\u043c\u0430\u0433\u0430\u0437\u0438\u043d | \u043b\u0435\u0440\u0443\u0430 | \u0442\u043e\u0432\u0430\u0440 | \u0434\u043e\u0441\u0442\u0430\u0432\u043a\u0430 | \u043e\u0442\u0437\u044b\u0432",1926],[8,"\u0437\u0430\u043f\u0430\u0445 | \u043f\u0430\u0445\u043d\u0443\u0442\u044c | \u0432\u044b\u0432\u0435\u0442\u0440\u0438\u0432\u0430\u0442\u044c\u0441\u044f | \u0441\u0432\u0435\u0447\u0430 | \u0430\u0440\u043e\u043c\u0430\u0442",1774],[9,"\u043a\u0440\u0430\u0441\u043a\u0430 | \u043a\u0440\u0430\u0441\u0438\u0442\u044c | \u0441\u043b\u043e\u0439 | \u0446\u0432\u0435\u0442 | \u043f\u043e\u043a\u0440\u0430\u0441\u0438\u0442\u044c",1741],[10,"\u0441\u043c\u043e\u0442\u0440\u0435\u0442\u044c\u0441\u044f | \u043a\u0440\u0430\u0441\u0438\u0432\u043e | \u043f\u043e\u043d\u0440\u0430\u0432\u0438\u0442\u044c\u0441\u044f | \u0432\u044b\u0433\u043b\u044f\u0434\u0435\u0442\u044c | \u0432\u043d\u0435\u0448\u043d\u0438\u0439",1708],[11,"\u0437\u0430\u043c\u043e\u043a | \u043b\u0430\u043c\u0438\u043d\u0430\u0442 | \u0434\u0432\u0435\u0440\u044c | \u043a\u043b\u044e\u0447 | \u0443\u043a\u043b\u0430\u0434\u044b\u0432\u0430\u0442\u044c",1697],[12,"\u0434\u0432\u0435\u0440\u044c | \u043f\u0435\u0442\u043b\u044f | \u0434\u0432\u0435\u0440\u043d\u043e\u0439 | \u0434\u0432\u0435\u0440\u0446\u0430 | \u0440\u0443\u0447\u043a\u0430",1684],[13,"\u0430\u043a\u043a\u0443\u043c\u0443\u043b\u044f\u0442\u043e\u0440 | \u0431\u0430\u0442\u0430\u0440\u0435\u044f | \u0431\u0430\u0442\u0430\u0440\u0435\u0439\u043a\u0430 | \u0437\u0430\u0440\u044f\u0434\u043a\u0430 | \u0437\u0430\u0440\u044f\u0434",1634],[14,"\u0433\u043e\u0434 | \u043f\u043e\u043b\u044c\u0437\u043e\u0432\u0430\u0442\u044c\u0441\u044f | \u043f\u0440\u043e\u0441\u043b\u0443\u0436\u0438\u0442\u044c | \u043d\u0430\u0437\u0430\u0434 | \u0433\u0430\u0440\u0430\u043d\u0442\u0438\u044f",1516],[15,"\u0441\u0432\u0435\u0442\u0438\u043b\u044c\u043d\u0438\u043a | \u043b\u0430\u043c\u ...

# %%
documents = pd.DataFrame({"Document": docs,
                          "ID": range(len(docs)),
                          "Topic": topics})
documents_per_topic = documents.groupby(['Topic'], as_index=False).agg({'Document': ' '.join})
cleaned_docs = model._preprocess_text(documents_per_topic.Document.values)

# Extract vectorizer and analyzer from BERTopic
vectorizer = model.vectorizer_model
analyzer = vectorizer.build_analyzer()

# Extract features for Topic Coherence evaluation
words = vectorizer.get_feature_names()
tokens = [analyzer(doc) for doc in cleaned_docs]
dictionary = corpora.Dictionary(tokens)
corpus = [dictionary.doc2bow(token) for token in tokens]
topic_words = [[words for words, _ in model.get_topic(topic)] 
               for topic in range(len(set(topics))-1)]

# Evaluate
coherence_model = CoherenceModel(topics=topic_words, 
                                 texts=tokens, 
                                 corpus=corpus,
                                 dictionary=dictionary, 
                                 coherence='c_v')
coherence = coherence_model.get_coherence()

nmpi_model = CoherenceModel(topics=topic_words, 
                                 texts=tokens, 
                                 corpus=corpus,
                                 dictionary=dictionary, 
                                 coherence='c_npmi')
nmpi = nmpi_model.get_coherence()

u_mass_model = CoherenceModel(topics=topic_words, 
                                 texts=tokens, 
                                 corpus=corpus,
                                 dictionary=dictionary, 
                                 coherence='u_mass')
u_mass = u_mass_model.get_coherence()

print("BERTOPIC model")
print ("coherence: {}".format(coherence))
print("nmpi: {}".format(nmpi))
print("mass: {}".format(u_mass))
# Out:
# BERTOPIC model
# coherence: 0.652033346626809
# nmpi: 0.14749986082419472
# mass: -0.4063863378463766

# %% [markdown]
# # NMF

# %%
X_token = []

for index in range(len(docs)):
    X_token.append(docs[index].split())

dictionary = corpora.Dictionary(X_token)
corpus = [dictionary.doc2bow(text) for text in X_token]

#Model
nmf = Nmf(corpus, num_topics=100, id2word=dictionary)
nmf_topics = nmf.print_topics(num_words=10)

for i,topic in enumerate(nmf_topics):
    print("\nTopic #{}:".format(i))
    print(topic)
    print("-"*70)
# Out:
# Topic #0:
# (40, '0.052*"провод" + 0.018*"розетка" + 0.014*"отверстие" + 0.012*"корпус" + 0.011*"светильник" + 0.011*"инструмент" + 0.009*"кабель" + 0.008*"нужный" + 0.007*"подключать" + 0.007*"материал"')
# ----------------------------------------------------------------------
#
# Topic #1:
# (63, '0.081*"приобретать" + 0.068*"окно" + 0.043*"крепление" + 0.020*"пластиковый" + 0.020*"дом" + 0.017*"сетка" + 0.014*"комплект" + 0.008*"штора" + 0.006*"собирать" + 0.006*"сборка"')
# ----------------------------------------------------------------------
#
# Topic #2:
# (65, '0.108*"знать" + 0.054*"панель" + 0.038*"клей" + 0.026*"купить" + 0.017*"обычный" + 0.014*"монтаж" + 0.010*"кабель" + 0.007*"пвх" + 0.006*"плинтус" + 0.006*"общий"')
# ----------------------------------------------------------------------
#
# Topic #3:
# (95, '0.153*"рука" + 0.015*"держать" + 0.012*"упаковка" + 0.010*"инструмент" + 0.010*"лежать" + 0.008*"легко" + 0.008*"материал" + 0.007*"расти" + 0.005*"кривой" + 0.005*"диск"')
# ----------------------------------------------------------------------
#
# Topic #4:
# (35, '0.237*"мочь" + 0.054*"сказать" + 0.011*"понимать" + 0.006*"находить" + 0.004*"человек" + 0.004*"знать" + 0.003*"дело" + 0.003*"случай" + 0.003*"вопрос" + 0.003*"мастер"')
# ----------------------------------------------------------------------
#
# Topic #5:
# (22, '0.128*"думать" + 0.051*"брак" + 0.050*"выбирать" + 0.025*"друг" + 0.017*"собирать" + 0.016*"доска" + 0.016*"ламинат" + 0.011*"пачка" + 0.011*"оказываться" + 0.009*"пакет"')
# ----------------------------------------------------------------------
#
# Topic #6:
# (98, '0.190*"леруа" + 0.054*"мерлен" + 0.017*"спасибо" + 0.016*"сотрудник" + 0.008*"продавать" + 0.006*"находить" + 0.005*"приезжать" + 0.005*"сказать" + 0.004*"продавец" + 0.004*"сервис"')
# ----------------------------------------------------------------------
#
# Topic #7:
# (48, '0.207*"работа" + 0.013*"инструмент" + 0.007*"диск" + 0.006*"выполнять" + 0.004*"мелкий" + 0.004*"аппарат" + 0.004*"болгарка" + 0.004*"бетон" + 0.003*"металл" + 0.003*"мощность"')
# ----------------------------------------------------------------------
#
# Topic #8:
# (78, '0.276*"работать" + 0.011*"переставать" + 0.008*"нормально" + 0.008*"насос" + 0.007*"нарекание" + 0.005*"инструмент" + 0.005*"исправно" + 0.004*"тихо" + 0.004*"подключать" + 0.004*"приятно"')
# ----------------------------------------------------------------------
#
# Topic #9:
# (62, '0.089*"достаточно" + 0.049*"оставлять" + 0.047*"качественный" + 0.034*"прочный" + 0.028*"материал" + 0.021*"иметь" + 0.016*"небольшой" + 0.012*"вид" + 0.009*"высокий" + 0.008*"покрытие"')
# ----------------------------------------------------------------------
#
# Topic #10:
# (2, '0.397*"отличный" + 0.017*"смотреться" + 0.012*"ламинат" + 0.008*"качество" + 0.005*"спасибо" + 0.005*"супер" + 0.005*"решение" + 0.005*"светильник" + 0.005*"приятный" + 0.005*"красивый"')
# ----------------------------------------------------------------------
#
# Topic #11:
# (86, '0.249*"белый" + 0.019*"грунт" + 0.016*"смотреться" + 0.014*"серый" + 0.013*"свет" + 0.011*"затирка" + 0.010*"желтый" + 0.009*"потолок" + 0.008*"черный" + 0.007*"высыхание"')
# ----------------------------------------------------------------------
#
# Topic #12:
# (59, '0.116*"пена" + 0.053*"баллон" + 0.037*"пистолет" + 0.013*"окно" + 0.010*"монтажный" + 0.009*"поставлять" + 0.009*"выходить" + 0.009*"пластиковый" + 0.007*"выход" + 0.007*"полностью"')
# ----------------------------------------------------------------------
#
# Topic #13:
# (14, '0.219*"клей" + 0.036*"клеить" + 0.015*"приклеивать" + 0.014*"блок" + 0.013*"обои" + 0.009*"держать" + 0.007*"шов" + 0.007*"склеивать" + 0.007*"стык" + 0.006*"инструкция"')
# ----------------------------------------------------------------------
#
# Topic #14:
# (56, '0.161*"потолок" + 0.041*"стена" + 0.041*"краска" + 0.018*"светильник" + 0.017*"красить" + 0.017*"люстра" + 0.012*"валик" + 0.012*"натяжной" + 0.009*"слой" + 0.007*"хороший"')
# ----------------------------------------------------------------------
#
# Topic #15:
# (72, '0.247*"слой" + 0.023*"лак" + 0.021*"покрывать" + 0.015*"тонкий" + 0.012*"штукатурка" + 0.010*"ложиться" + 0.009*"толстый" + 0.009*"расход" + 0.008*"красить" + 0.008*"сохнуть"')
# ----------------------------------------------------------------------
#
# Topic #16:
# (99, '0.192*"наносить" + 0.053*"лак" + 0.018*"кисть" + 0.012*"дерево" + 0.011*"грунтовка" + 0.010*"шпатель" + 0.009*"валик" + 0.008*"грунт" + 0.007*"покрывать" + 0.007*"штукатурка"')
# ----------------------------------------------------------------------
#
# Topic #17:
# (41, '0.207*"обои" + 0.034*"клеить" + 0.024*"стык" + 0.019*"рисунок" + 0.017*"поклейка" + 0.015*"рулон" + 0.015*"пузырь" + 0.012*"видно" + 0.011*"клеиться" + 0.009*"поклеить"')
# ----------------------------------------------------------------------
#
# Topic #18:
# (74, '0.303*"краска" + 0.033*"ложиться" + 0.011*"покрасить" + 0.008*"консультант" + 0.007*"перекрашивать" + 0.006*"пятно" + 0.006*"ровно" + 0.006*"матовый" + 0.006*"банка" + 0.006*"расход"')
# ----------------------------------------------------------------------
#
# Topic #19:
# (31, '0.185*"краска" + 0.071*"красить" + 0.033*"слой" + 0.021*"покраска" + 0.013*"запах" + 0.012*"банка" + 0.009*"банк" + 0.009*"грунтовка" + 0.008*"покрасить" + 0.008*"дерево"')
# ----------------------------------------------------------------------

# %% [markdown]
# # LDA

# %%
lda = LdaModel(corpus, num_topics=100 ,  id2word=dictionary)
lda_topics = lda.print_topics(num_words=10)

for i,topic in enumerate(lda_topics):
    print("\nTopic #{}:".format(i))
    print(topic)
    print("-"*70)
# Out:
# Topic #0:
# (76, '0.156*"дизайн" + 0.137*"интерьер" + 0.100*"дорогой" + 0.081*"низкий" + 0.075*"качество" + 0.061*"деталь" + 0.057*"цена" + 0.041*"пять" + 0.031*"бренд" + 0.031*"изначально"')
# ----------------------------------------------------------------------
#
# Topic #1:
# (30, '0.131*"полный" + 0.117*"заказ" + 0.086*"радиатор" + 0.062*"вскрывать" + 0.052*"входить" + 0.048*"освещать" + 0.035*"шуруп" + 0.027*"смотря" + 0.026*"горячий" + 0.026*"разочарование"')
# ----------------------------------------------------------------------
#
# Topic #2:
# (77, '0.224*"упаковка" + 0.133*"ужасный" + 0.094*"претензия" + 0.094*"качество" + 0.077*"друг" + 0.047*"достойный" + 0.040*"компактный" + 0.035*"сверху" + 0.031*"аналог" + 0.029*"иметься"')
# ----------------------------------------------------------------------
#
# Topic #3:
# (3, '0.179*"лампочка" + 0.132*"минута" + 0.069*"уходить" + 0.060*"просвечивать" + 0.055*"холодный" + 0.046*"снова" + 0.039*"расход" + 0.038*"начинать" + 0.024*"тк" + 0.024*"время"')
# ----------------------------------------------------------------------
#
# Topic #4:
# (25, '0.368*"легко" + 0.143*"небольшой" + 0.060*"стоимость" + 0.048*"считать" + 0.040*"основной" + 0.031*"красота" + 0.030*"мыться" + 0.028*"наверное" + 0.025*"слабый" + 0.022*"приличный"')
# ----------------------------------------------------------------------
#
# Topic #5:
# (49, '0.125*"интересный" + 0.093*"сила" + 0.081*"зря" + 0.080*"висеть" + 0.043*"начинаться" + 0.043*"фартук" + 0.039*"ряд" + 0.038*"кромка" + 0.033*"натуральный" + 0.028*"номер"')
# ----------------------------------------------------------------------
#
# Topic #6:
# (42, '0.266*"товар" + 0.184*"материал" + 0.114*"угол" + 0.105*"менять" + 0.045*"покупатель" + 0.024*"пропускать" + 0.023*"мешать" + 0.020*"причина" + 0.020*"некачественный" + 0.019*"узнавать"')
# ----------------------------------------------------------------------
#
# Topic #7:
# (95, '0.410*"работать" + 0.071*"ребенок" + 0.064*"нарекание" + 0.050*"постоянно" + 0.049*"надеяться" + 0.045*"уровень" + 0.042*"приезжать" + 0.035*"купить" + 0.026*"брать" + 0.026*"гараж"')
# ----------------------------------------------------------------------
#
# Topic #8:
# (59, '0.321*"вид" + 0.119*"внешний" + 0.062*"перегорать" + 0.052*"балкон" + 0.043*"состояние" + 0.035*"запас" + 0.033*"мера" + 0.026*"значит" + 0.026*"пластика" + 0.024*"повреждение"')
# ----------------------------------------------------------------------
#
# Topic #9:
# (2, '0.069*"жалеть" + 0.051*"фасад" + 0.048*"должно" + 0.047*"производить" + 0.040*"расстраивать" + 0.036*"платить" + 0.033*"великолепно" + 0.033*"подымать" + 0.031*"пузыриться" + 0.031*"дважды"')
# ----------------------------------------------------------------------
#
# Topic #10:
# (93, '0.150*"первый" + 0.136*"делать" + 0.070*"второй" + 0.060*"вернуть" + 0.058*"купить" + 0.057*"впечатление" + 0.044*"вопрос" + 0.043*"возврат" + 0.039*"срок" + 0.035*"сегодня"')
# ----------------------------------------------------------------------
#
# Topic #11:
# (70, '0.329*"сделать" + 0.185*"хотеть" + 0.148*"сказать" + 0.055*"форма" + 0.048*"недорогой" + 0.024*"гипс" + 0.022*"купить" + 0.018*"расходиться" + 0.015*"взять" + 0.015*"встречать"')
# ----------------------------------------------------------------------
#
# Topic #12:
# (61, '0.233*"дверь" + 0.149*"оказываться" + 0.113*"думать" + 0.098*"люстра" + 0.038*"купить" + 0.038*"равный" + 0.031*"открывать" + 0.025*"приходиться" + 0.017*"покупать" + 0.017*"тянуться"')
# ----------------------------------------------------------------------
#
# Topic #13:
# (66, '0.163*"лента" + 0.159*"снимать" + 0.080*"однозначно" + 0.055*"находиться" + 0.055*"крышка" + 0.053*"везде" + 0.046*"близко" + 0.041*"бесполезный" + 0.036*"влага" + 0.035*"составлять"')
# ----------------------------------------------------------------------
#
# Topic #14:
# (44, '0.152*"розетка" + 0.113*"модель" + 0.090*"правда" + 0.056*"подключать" + 0.045*"стойка" + 0.035*"спокойно" + 0.033*"светодиод" + 0.032*"сервис" + 0.030*"линия" + 0.028*"экспертиза"')
# ----------------------------------------------------------------------
#
# Topic #15:
# (52, '0.078*"полка" + 0.069*"пленка" + 0.067*"усилие" + 0.050*"образовываться" + 0.050*"переживать" + 0.049*"китайский" + 0.047*"класс" + 0.043*"подумать" + 0.042*"особый" + 0.036*"визуально"')
# ----------------------------------------------------------------------
#
# Topic #16:
# (89, '0.098*"сожаление" + 0.080*"внутренний" + 0.076*"раствор" + 0.064*"учитывать" + 0.055*"вставлять" + 0.051*"скотч" + 0.038*"приходиться" + 0.034*"отделка" + 0.030*"уставать" + 0.029*"поводить"')
# ----------------------------------------------------------------------
#
# Topic #17:
# (20, '0.131*"сломаться" + 0.113*"тонкий" + 0.094*"пластик" + 0.080*"смотреть" + 0.071*"аккуратно" + 0.071*"целый" + 0.060*"выбрасывать" + 0.058*"дома" + 0.051*"трещина" + 0.049*"острый"')
# ----------------------------------------------------------------------
#
# Topic #18:
# (79, '0.195*"разный" + 0.100*"неделя" + 0.078*"оттенок" + 0.075*"длина" + 0.069*"неплохой" + 0.050*"темный" + 0.049*"добавлять" + 0.049*"смочь" + 0.045*"некоторый" + 0.036*"тип"')
# ----------------------------------------------------------------------
#
# Topic #19:
# (47, '0.220*"свет" + 0.152*"удобно" + 0.104*"освещение" + 0.086*"яркий" + 0.054*"дешево" + 0.045*"переставать" + 0.044*"поменять" + 0.025*"закреплять" + 0.023*"садиться" + 0.019*"мерцать"')
# ----------------------------------------------------------------------

# %% [markdown]
# # Quality

# %%
#quality fuctions
def coherence_f(model, texts, dictionary):
    coherence = CoherenceModel(model=model, texts=texts,
        dictionary=dictionary, coherence='c_v')
    return coherence.get_coherence()

def nmpi_f(model, texts, dictionary):
    nmpi = CoherenceModel(model=model, texts=texts,
        dictionary=dictionary, coherence='c_npmi')
    return nmpi.get_coherence()

def mass_f(model, texts, dictionary):   
    mass = CoherenceModel(model=model, texts=texts,
        dictionary=dictionary, coherence='u_mass')
    return mass.get_coherence()

# %%
print("NMF model")
print ("coherence: {}".format(coherence_f(model=nmf, texts=X_token, dictionary=dictionary)))
print("nmpi: {}".format(nmpi_f(model=nmf, texts=X_token, dictionary=dictionary)))
print("mass: {}".format(mass_f(model=nmf, texts=X_token, dictionary=dictionary)))
# Out:
# NMF model
# coherence: 0.5959593812120916
# nmpi: 0.04190082875729775
# mass: -3.982464334606963

# %%
print("LDA model")
print ("coherence: {}".format(coherence_f(model=lda, texts=X_token, dictionary=dictionary)))
print("nmpi: {}".format(nmpi_f(model=lda, texts=X_token, dictionary=dictionary)))
print("mass: {}".format(mass_f(model=lda, texts=X_token, dictionary=dictionary)))
# Out:
# LDA model
# coherence: 0.37572598764985365
# nmpi: -0.10185296511322636
# mass: -6.562132526283091
