# %% [markdown]
# <a href="https://colab.research.google.com/github/alya-atm/Reviews-summarization-for-product-description/blob/main/topic_modeling_BigArtm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bigartm10
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: bigartm10 in /usr/local/lib/python3.8/dist-packages (0.10.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from bigartm10) (1.3.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from bigartm10) (4.64.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from bigartm10) (1.21.6)
# Requirement already satisfied: protobuf>=3.0 in /usr/local/lib/python3.8/dist-packages (from bigartm10) (3.19.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from bigartm10) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->bigartm10) (3.0.9)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->bigartm10) (2022.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->bigartm10) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas->bigartm10) (1.15.0)

# %%
import artm 
import pandas as pd
import glob
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np
from os.path import join
from collections import Counter
from gensim.models import  CoherenceModel
from gensim import corpora

# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
path = '/content/drive/My Drive/review_summarization/'

# %%
comments = pd.read_csv('/content/drive/My Drive/review_summarization/comments_clean.csv')

# %%
X = comments['clean_body']

# %%
number_topics = 75
topic_names = ['topic_{}'.format(i) for i in range(number_topics)]

# %% [markdown]
# Prepare data for model, batch vectorization

# %%
texts = comments['clean_body'].tolist()

# %%
token_frequencies  = []
for text in texts:
  counter = dict(Counter(text.split()))
  token_frequencies.append([(key + ':' + str(value)) for key, value in counter.items()])

# %%
with open(join(path, 'data_comments'), 'w') as file:
        for n in range(len(texts)):
            file.write(f'doc{n} {" ".join(token_frequencies[n])}\n')

# %%
batch_vectorizer = artm.BatchVectorizer(data_path=join(path, 'data_comments'),
                                            data_format='vowpal_wabbit',
                                            target_folder=join(path, 'batches'))

# %% [markdown]
# Model

# %%
model_artm = artm.ARTM( num_topics=number_topics, 
                  topic_names=topic_names, 
              
                  scores=[artm.PerplexityScore(name='PerplexityScore',dictionary=batch_vectorizer.dictionary)],
                  regularizers=[artm.SmoothSparseThetaRegularizer(name='SparseTheta',tau=-0.55)],
                  cache_theta = True)

# %%
model_artm.scores.add(artm.TopTokensScore(name='TopTokensScore',num_tokens=10))
model_artm.scores.add(artm.SparsityThetaScore(name='SparsityThetaScore'))
model_artm.scores.add(artm.SparsityThetaScore(name='SparsityPhiScore'))
model_artm.scores.add(artm.TopicKernelScore(name='TopicKernelScore',
                                                  probability_mass_threshold=0.5))

model_artm.regularizers.add(artm.SmoothSparsePhiRegularizer(name='sparse_phi_reg',tau = -0.25))
model_artm.regularizers.add(artm.SmoothSparseThetaRegularizer(name='sparse_theta_reg',tau = -1))
model_artm.regularizers.add(artm.DecorrelatorPhiRegularizer(name='decorellator_phi_reg',tau = 10))

# %%
model_artm.initialize(dictionary=batch_vectorizer.dictionary)
model_artm.num_document_passes = 1
model_artm.fit_offline(batch_vectorizer=batch_vectorizer, num_collection_passes=25)

# %%
for i, topic_name in enumerate(model_artm.topic_names):
      print("\nTopic #{}:".format(i))
      print(model_artm.score_tracker['TopTokensScore'].last_tokens[topic_name])
      print("-"*70)
# Out:
# Topic #0:
# ['затирка', 'шов', 'цвет', 'плитка', 'очень', 'получаться', 'затирать', 'белый', 'лезвие', 'весь']
# ----------------------------------------------------------------------
#
# Topic #1:
# ['плита', 'утеплитель', 'материал', 'стена', 'очень', 'дом', 'вата', 'весь', 'мм', 'кнауф']
# ----------------------------------------------------------------------
#
# Topic #2:
# ['запах', 'средство', 'весь', 'перчатка', 'очень', 'ожидание', 'вонять', 'превосходить', 'пахнуть', 'купить']
# ----------------------------------------------------------------------
#
# Topic #3:
# ['колесо', 'нож', 'рубанок', 'тачка', 'купить', 'весь', 'очень', 'кг', 'ограничитель', 'строгать']
# ----------------------------------------------------------------------
#
# Topic #4:
# ['очень', 'купить', 'stanley', 'справа', 'слева', 'поливать', 'вместительный', 'цена', 'салфетка', 'леруа']
# ----------------------------------------------------------------------
#
# Topic #5:
# ['стеллаж', 'полка', 'собирать', 'уголок', 'стойка', 'сборка', 'комплект', 'весь', 'купить', 'очень']
# ----------------------------------------------------------------------
#
# Topic #6:
# ['шпаклевка', 'стена', 'слой', 'плинтус', 'очень', 'поверхность', 'наноситься', 'грунтовка', 'наносить', 'легко']
# ----------------------------------------------------------------------
#
# Topic #7:
# ['вводить', 'заблуждение', 'товар', 'магазин', 'покупатель', 'сайт', 'леруа', 'очень', 'отзыв', 'производитель']
# ----------------------------------------------------------------------
#
# Topic #8:
# ['клей', 'гвоздь', 'склеивать', 'налет', 'очень', 'молоток', 'весь', 'который', 'вода', 'поверхность']
# ----------------------------------------------------------------------
#
# Topic #9:
# ['датчик', 'масло', 'работать', 'заводиться', 'бензин', 'купить', 'весь', 'очень', 'генератор', 'проблема']
# ----------------------------------------------------------------------
#
# Topic #10:
# ['краска', 'слой', 'красить', 'покрасить', 'стена', 'цвет', 'очень', 'ложиться', 'наносить', 'покраска']
# ----------------------------------------------------------------------
#
# Topic #11:
# ['воздух', 'вентилятор', 'шум', 'увлажнитель', 'клапан', 'работать', 'очень', 'поток', 'комната', 'весь']
# ----------------------------------------------------------------------
#
# Topic #12:
# ['магазин', 'товар', 'возврат', 'леруа', 'данный', 'мерлен', 'сотрудник', 'сказать', 'купить', 'день']
# ----------------------------------------------------------------------
#
# Topic #13:
# ['очень', 'купить', 'весь', 'год', 'подарок', 'склад', 'леруа', 'магазин', 'просто', 'январь']
# ----------------------------------------------------------------------
#
# Topic #14:
# ['подложка', 'пол', 'швабра', 'очень', 'весь', 'ряд', 'стелить', 'укладываться', 'купить', 'мм']
# ----------------------------------------------------------------------
#
# Topic #15:
# ['болт', 'гайка', 'ключ', 'затягивать', 'винт', 'резьба', 'закручивать', 'приходиться', 'купить', 'откручивать']
# ----------------------------------------------------------------------
#
# Topic #16:
# ['доска', 'вагонка', 'сучок', 'весь', 'щит', 'качество', 'переходник', 'магазин', 'очень', 'мм']
# ----------------------------------------------------------------------
#
# Topic #17:
# ['трава', 'косить', 'участок', 'триммер', 'газон', 'сотка', 'катушка', 'леска', 'год', 'купить']
# ----------------------------------------------------------------------
#
# Topic #18:
# ['кабель', 'провод', 'компрессор', 'изоляция', 'мм', 'сечение', 'работать', 'очень', 'купить', 'весь']
# ----------------------------------------------------------------------
#
# Topic #19:
# ['раковина', 'тумба', 'столешница', 'ножка', 'очень', 'стол', 'весь', 'купить', 'подходить', 'дверца']
# ----------------------------------------------------------------------
#
# Topic #20:
# ['штора', 'очень', 'ткань', 'карниз', 'тюль', 'цвет', 'крючок', 'смотреться', 'купить', 'штанга']
# ----------------------------------------------------------------------
#
# Topic #21:
# ['диск', 'резать', 'болгарка', 'розетка', 'рез', 'работа', 'очень', 'работать', 'купить', 'мм']
# ----------------------------------------------------------------------
#
# Topic #22:
# ['лента', 'вытяжка', 'генератор', 'профиль', 'весь', 'очень', 'работать', 'коннектор', 'сделать', 'купить']
# ----------------------------------------------------------------------
#
# Topic #23:
# ['брусок', 'брус', 'магазин', 'весь', 'выбирать', 'дрова', 'кривой', 'леруа', 'образец', 'поставщик']
# ----------------------------------------------------------------------
#
# Topic #24:
# ['аккумулятор', 'блок', 'устройство', 'зарядка', 'очень', 'работать', 'цепь', 'купить', 'работа', 'заряд']
# ----------------------------------------------------------------------
#
# Topic #25:
# ['коробка', 'магазин', 'проверять', 'упаковка', 'весь', 'коробок', 'товар', 'брак', 'онлайн', 'очень']
# ----------------------------------------------------------------------
#
# Topic #26:
# ['цемент', 'работа', 'очень', 'весь', 'кладка', 'бетон', 'кирпич', 'фундамент', 'миксер', 'работать']
# ----------------------------------------------------------------------
#
# Topic #27:
# ['смеситель', 'кран', 'вода', 'шланг', 'лейка', 'очень', 'год', 'хороший', 'купить', 'душа']
# ----------------------------------------------------------------------
#
# Topic #28:
# ['рассада', 'очень', 'весь', 'таймер', 'посадить', 'корень', 'год', 'теплица', 'купить', 'работать']
# ----------------------------------------------------------------------
#
# Topic #29:
# ['лестница', 'очень', 'весь', 'стремянка', 'хороший', 'цена', 'купить', 'качество', 'магазин', 'контейнер']
# ----------------------------------------------------------------------
#
# Topic #30:
# ['платить', 'скупой', 'очень', 'спирит', 'уайт', 'весь', 'купить', 'фаска', 'цена', 'блеск']
# ----------------------------------------------------------------------
#
# Topic #31:
# ['радиатор', 'ковер', 'очень', 'комната', 'весь', 'цвет', 'тепло', 'год', 'квартира', 'греть']
# ----------------------------------------------------------------------
#
# Topic #32:
# ['магазин', 'день', 'сервисный', 'центр', 'гарантия', 'леруа', 'сервис', 'купить', 'сказать', 'гарантийный']
# ----------------------------------------------------------------------
#
# Topic #33:
# ['магнит', 'окно', 'подоконник', 'угол', 'уплотнитель', 'подставка', 'распил', 'очень', 'угольник', 'весь']
# ----------------------------------------------------------------------
#
# Topic #34:
# ['лампа', 'люстра', 'светить', 'очень', 'ярко', 'плафон', 'свет', 'купить', 'светодиодный', 'вт']
# ----------------------------------------------------------------------
#
# Topic #35:
# ['цвет', 'лак', 'покрывать', 'слой', 'очень', 'бежевый', 'серый', 'оттенок', 'коричневый', 'белый']
# ----------------------------------------------------------------------
#
# Topic #36:
# ['очень', 'инструмент', 'скоба', 'работа', 'работать', 'пружина', 'купить', 'цена', 'рука', 'шурик']
# ----------------------------------------------------------------------
#
# Topic #37:
# ['клей', 'приклеивать', 'клеиться', 'клеить', 'фанера', 'лист', 'бит', 'приклеиваться', 'стена', 'весь']
# ----------------------------------------------------------------------
#
# Topic #38:
# ['ящик', 'шкаф', 'очень', 'собирать', 'весь', 'полк', 'стенка', 'сборка', 'купить', 'комод']
# ----------------------------------------------------------------------
#
# Topic #39:
# ['очень', 'шкафчик', 'весь', 'трубка', 'звук', 'мыло', 'фартук', 'купить', 'издавать', 'вода']
# ----------------------------------------------------------------------
#
# Topic #40:
# ['перфоратор', 'работа', 'бур', 'работать', 'купить', 'бетон', 'год', 'инструмент', 'очень', 'брать']
# ----------------------------------------------------------------------
#
# Topic #41:
# ['плитка', 'клей', 'очень', 'весь', 'укладка', 'керамогранит', 'пол', 'стена', 'размер', 'хороший']
# ----------------------------------------------------------------------
#
# Topic #42:
# ['мешок', 'смесь', 'пол', 'штукатурка', 'вода', 'стяжка', 'заливать', 'раствор', 'очень', 'делать']
# ----------------------------------------------------------------------
#
# Topic #43:
# ['отзыв', 'свой', 'очень', 'риск', 'страх', 'весь', 'шторка', 'стыковаться', 'стенд', 'брать']
# ----------------------------------------------------------------------
#
# Topic #44:
# ['электрод', 'лопата', 'варить', 'снег', 'аппарат', 'купить', 'очень', 'сварка', 'шов', 'хороший']
# ----------------------------------------------------------------------
#
# Topic #45:
# ['пилить', 'пила', 'пилка', 'лобзик', 'пить', 'купить', 'очень', 'мм', 'работа', 'работать']
# ----------------------------------------------------------------------
#
# Topic #46:
# ['вода', 'мойка', 'горячий', 'бак', 'посуда', 'бойлер', 'нагрев', 'устанавливать', 'режим', 'температура']
# ----------------------------------------------------------------------
#
# Topic #47:
# ['батарея', 'очень', 'стул', 'цвет', 'весь', 'вздуваться', 'год', 'чугунный', 'купить', 'качество']
# ----------------------------------------------------------------------
#
# Topic #48:
# ['доставка', 'заказывать', 'привозить', 'заказ', 'магазин', 'товар', 'интернет', 'очень', 'весь', 'леруа']
# ----------------------------------------------------------------------
#
# Topic #49:
# ['сетка', 'рамка', 'рама', 'очень', 'инструкция', 'размер', 'купить', 'мм', 'луч', 'который']
# ----------------------------------------------------------------------
#
# Topic #50:
# ['унитаз', 'крышка', 'арматура', 'сидение', 'очень', 'кнопка', 'вода', 'весь', 'двойной', 'купить']
# ----------------------------------------------------------------------
#
# Topic #51:
# ['фильтр', 'вода', 'картридж', 'год', 'очень', 'весь', 'колба', 'купить', 'давление', 'система']
# ----------------------------------------------------------------------
#
# Topic #52:
# ['пылесос', 'мешок', 'пыль', 'насадка', 'мусор', 'очень', 'весь', 'купить', 'мангал', 'использовать']
# ----------------------------------------------------------------------
#
# Topic #53:
# ['труба', 'потечь', 'отопление', 'соединение', 'год', 'система', 'весь', 'полотенцесушитель', 'течь', 'купить']
# ----------------------------------------------------------------------
#
# Topic #54:
# ['обои', 'стена', 'рулон', 'рисунок', 'стык', 'очень', 'клей', 'клеить', 'весь', 'полоса']
# ----------------------------------------------------------------------
#
# Topic #55:
# ['сифон', 'слива', 'ванна', 'кронштейн', 'бачок', 'поддон', 'стекло', 'вода', 'весь', 'очень']
# ----------------------------------------------------------------------
#
# Topic #56:
# ['ламинат', 'замок', 'пачка', 'укладывать', 'очень', 'весь', 'укладка', 'брак', 'пол', 'цвет']
# ----------------------------------------------------------------------
#
# Topic #57:
# ['пена', 'баллон', 'пистолет', 'купить', 'очень', 'весь', 'использовать', 'хороший', 'клей', 'монтажный']
# ----------------------------------------------------------------------
#
# Topic #58:
# ['ведро', 'шпатлевка', 'гидроизоляция', 'рейка', 'шпатель', 'очень', 'мастика', 'слой', 'вода', 'наносить']
# ----------------------------------------------------------------------
#
# Topic #59:
# ['дюбель', 'сорт', 'саморез', 'горелка', 'очень', 'купить', 'который', 'весь', 'ru', 'пластина']
# ----------------------------------------------------------------------
#
# Topic #60:
# ['крыша', 'котел', 'батарейка', 'работать', 'год', 'кровля', 'весь', 'очень', 'купить', 'экран']
# ----------------------------------------------------------------------
#
# Topic #61:
# ['дверь', 'петля', 'замок', 'ручка', 'очень', 'установка', 'устанавливать', 'купить', 'весь', 'коробка']
# ----------------------------------------------------------------------
#
# Topic #62:
# ['насос', 'вода', 'работать', 'год', 'качать', 'напор', 'купить', 'скважина', 'метр', 'очень']
# ----------------------------------------------------------------------
#
# Topic #63:
# ['плесень', 'обрабатывать', 'обработка', 'стена', 'средство', 'грибок', 'добавка', 'весь', 'использовать', 'шумоизоляция']
# ----------------------------------------------------------------------
#
# Topic #64:
# ['отверстие', 'сверло', 'просверливать', 'дрель', 'патрон', 'мм', 'шуруповерт', 'сверлить', 'купить', 'очень']
# ----------------------------------------------------------------------
#
# Topic #65:
# ['елка', 'очень', 'ветка', 'гирлянда', 'красивый', 'игрушка', 'купить', 'весь', 'рулетка', 'светодиод']
# ----------------------------------------------------------------------
#
# Topic #66:
# ['обогреватель', 'очень', 'работать', 'купить', 'станция', 'весь', 'год', 'газ', 'работа', 'обогрев']
# ----------------------------------------------------------------------
#
# Topic #67:
# ['лампочка', 'водонагреватель', 'купить', 'отключение', 'работать', 'вода', 'год', 'перегорать', 'электричество', 'квт']
# ----------------------------------------------------------------------
#
# Topic #68:
# ['очень', 'цвет', 'колеровка', 'однородный', 'хороший', 'весь', 'декор', 'шикарно', 'тон', 'просто']
# ----------------------------------------------------------------------
#
# Topic #69:
# ['свет', 'яркий', 'пульт', 'освещение', 'очень', 'режим', 'подсветка', 'яркость', 'работать', 'комната']
# ----------------------------------------------------------------------
#
# Topic #70:
# ['обои', 'стена', 'клеить', 'очень', 'поклейка', 'пузырь', 'поклеить', 'весь', 'просвечивать', 'стык']
# ----------------------------------------------------------------------
#
# Topic #71:
# ['светильник', 'канал', 'купить', 'очень', 'весь', 'работать', 'антенна', 'освещать', 'качество', 'ватт']
# ----------------------------------------------------------------------
#
# Topic #72:
# ['грунт', 'цветок', 'растение', 'семя', 'очень', 'горшок', 'весь', 'восходить', 'купить', 'хороший']
# ----------------------------------------------------------------------
#
# Topic #73:
# ['сверлить', 'коронка', 'оборот', 'сверление', 'мм', 'ступень', 'лдсп', 'сделать', 'работать', 'бетон']
# ----------------------------------------------------------------------
#
# Topic #74:
# ['линолеум', 'очень', 'сушилка', 'весь', 'ролик', 'веревка', 'год', 'клавиша', 'постилать', 'выключатель']
# ----------------------------------------------------------------------

# %%
topics2 = [model_artm.score_tracker['TopTokensScore'].last_tokens[topic_name] for topic_name in model_artm.topic_names]

# %%
def coherence( topics, texts, dictionary):
    coherence = CoherenceModel(topics=topics, texts=texts,
        dictionary=dictionary, coherence='c_v')
    return coherence.get_coherence()

def nmpi(topics, texts, dictionary):
    nmpi = CoherenceModel(topics=topics, texts=texts,
        dictionary=dictionary, coherence='c_npmi')
    return nmpi.get_coherence()

def mass(topics, texts, dictionary):   
    mass = CoherenceModel(topics=topics, texts=texts,
        dictionary=dictionary, coherence='u_mass')
    return mass.get_coherence()

# %%
X_token = []

for index in range(len(X)):
    X_token.append(X[index].split())

dictionary = corpora.Dictionary(X_token)

# %%
print("BigArtm model")
print ("coherence: {}".format(coherence( topics2, X_token, dictionary)))
print("nmpi: {}".format(nmpi( topics2, X_token, dictionary)))
print("mass: {}".format(mass( topics2, X_token, dictionary)))
# Out:
# BigArtm model
# coherence: 0.5939930908593856
# nmpi: 0.057380060177706284
# mass: -3.4436995630965868
